# %%
import pandas as pd

# %%
pd.read_csv("data/서울특별시 강남구_옥상간판 설치 현황_20230927.csv", encoding="cp949")
# Out:
#     연번                           광고물 표시 주소    허가(연장)일자  \
# 0    1             서울특별시 강남구 언주로 703 (논현동)  2020-09-08
# 1    2       서울특별시 강남구 도산대로 306  옥상층 (논현동)  2020-09-09
# 2    3            서울특별시 강남구 강남대로 642 (신사동)  2020-09-18
# 3    4             서울특별시 강남구 언주로 708 (논현동)  2020-10-25
# 4    5             서울특별시 강남구 언주로 651 (논현동)  2020-10-27
# ..  ..                                 ...         ...
# 71  72            서울특별시 강남구 봉은사로 641 (삼성동)  2023-05-28
# 72  73            서울특별시 강남구 영동대로 312 (대치동)  2023-06-29
# 73  74  서울특별시 강남구 도산대로 127  5층 (신사동  경서빌딩)  2023-07-06
# 74  75             서울특별시 강남구 도곡로 454 (대치동)  2023-07-31
# 75  76          서울특별시 강남구 남부순환로 3008 (대치동)  2023-08-24
#
#                                 규격
# 0   18.7*8   19*8   19*8   18.7*8
# 1               10*9 15.2*9 15.2*9
# 2                         12*9.04
# 3        5.4*6.8 10.8*6.8 10.8*6.8
# 4                             16*9
# ..                             ...
# 71                      17.55*6.7
# ...
